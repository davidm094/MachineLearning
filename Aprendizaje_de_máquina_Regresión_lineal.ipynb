# %% [markdown]
# <a href="https://colab.research.google.com/github/davidm094/MachineLearning/blob/main/Aprendizaje_de_ma%CC%81quina_Regresio%CC%81n_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# # Aprendizaje de máquina - Laboratorio: Regresión lineal
# En este notebook vamos a explorar la implementación de un modelo de regresión lineal usando Python básico y la librería [NumPy](numpy.org).

# %% [markdown]
# ## Setup
#
# Importaremos las librerías necesarias para el ejercicio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## Regresión lineal
#
# La regresión lineal es el modelo más simple de aprendizaje de máquina supervisado. El modelo asume que la relación entre las variables independientes y dependientes es aproximadamente lineal.
#
# La tarea de una hipótesis de regresión lineal es estimar la variable objetivo $\hat{y}$ encontrando un vector de pesos $\mathbf{\theta}$  un término de sesgo  $\theta_0$ al minimizar una función de pérdida sobre un conjunto de entrenamiento de datos ($x_{i},y_{i})$.
#
# $ \underset{\mathbf{w}_{*},b_{*}}\min \mathscr{L}( y,\mathbf{x}^\top\mathbf{w}+ b )$

# %% [markdown]
# ## Caso de estudio - Costos médicos
#
# Es este caso de estudio usaremos los datos de costos de una compañia de seguros médicos. El dataset cuenta con información acerca de los asegurados (edad, sexo, bmi, hijos, fuma, región) y los costos que tuvo para la compañia esa persona.
#
# Algunos costos en los que incurre la compañia de seguros pueden estar asociados a eventos fortuitos, pero se espera que ciertas poblaciones (personas de más edad o fumadores por ejemplo) impliquen mayores costos para las compañias.
#
# Teniendo en cuenta los datos históricos de la compañia de seguros médicos, La compañia quiere estimar el costo de pacientes nuevos para poder ajustar mejor su esquema de costos y financiación.
#
#
# ### Créditos
#
# El dataset de costos médicos es un dataset sintético creado para el libro Machine Learning with R (2nd. ed.) Brett Lantz. Packt Publishing.

# %% [markdown]
# ## Exploración de datos
#
# En esta sección entenderemos mejor los datos que tenemos mediante un análisis descriptivo de los datos. Para eso utilizaremos la librería [pandas ](https://pandas.pydata.org/) para cargar la información, y  [matplotlib](https:/matplotlib.org/) para visualizar la relación entre algunas variables.

# %% [markdown]
# ### Pandas library
#
# Antes de comenzar la exploración, se realizará una pequeña guia de uso de Pandas
#
# Pandas is una libreria para la extracción y manipulación de información tabular en Python. Se mostrará el uso de Pandas mediante algunas funciones importantes para la manipulación de datos

# %%
# Creación de objeto pandas dataframe
patients_df=pd.read_csv('https://github.com/stedy/Machine-Learning-with-R-datasets/blob/master/insurance.csv?raw=true')

# %%
# La función type nos ayuda a saber qué tipo de objeto tenemos en una variable
type(patients_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Podemos también desplegar ayuda sobre el objeto
#help(patients_df)
patients_df?

# %%
#Imprimimos por pantalla la información
patients_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Muestreo inicial de datos
patients_df.sample(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 321    26  female  29.640         4     no  northeast  24671.66334
# 272    41    male  37.050         2     no  northwest   7265.70250
# 544    54    male  30.210         0     no  northwest  10231.49990
# 26     63  female  23.085         0     no  northeast  14451.83515
# 727    29  female  21.755         1    yes  northeast  16657.71745
# 335    64    male  34.500         0     no  southwest  13822.80300
# 802    21    male  22.300         1     no  southwest   2103.08000
# 1158   20  female  30.590         0     no  northeast   2459.72010
# 628    58    male  38.000         0     no  southwest  11365.95200
# 956    54    male  30.800         1    yes  southeast  41999.52000

# %%
# Primeras  5 filas
patients_df.head(5)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
patients_df.tail(5)
# Out:
#       age     sex    bmi  children smoker     region     charges
# 1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
# Shape (dimensiones) del DataFrame (1338 rows and 7 columns)
patients_df.shape
# Out:
# (1338, 7)

# %% [markdown]
# ### Pandas indexing
#
# Un dataframe de pandas tiene 2 índices: column index y rows index

# %%
# Indice de columnas
patients_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
# Indice de filas: 0 a 1338
patients_df.index
# Out:
# RangeIndex(start=0, stop=1338, step=1)

# %% [markdown]
# Los índices silrven para selecionar o filtrar elementos del Dataframe.

# %%
# Indexar una única columna, es un objeto Series
patients_df['age']
# Out:
# 0       19
# 1       18
# 2       28
# 3       33
# 4       32
#         ..
# 1333    50
# 1334    18
# 1335    18
# 1336    21
# 1337    61
# Name: age, Length: 1338, dtype: int64

# %%
type(patients_df['age'])
# Out:
# pandas.core.series.Series

# %%
# Indexar varias columnas crea un DataFrame
patients_df[['age','sex']]
# Out:
#       age     sex
# 0      19  female
# 1      18    male
# 2      28    male
# 3      33    male
# 4      32    male
# ...   ...     ...
# 1333   50    male
# 1334   18  female
# 1335   18  female
# 1336   21  female
# 1337   61  female
#
# [1338 rows x 2 columns]

# %%
# Index filas 10 to 20 (loc)
patients_df.loc[10:20]
# Out:
#     age     sex     bmi  children smoker     region      charges
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# 13   56  female  39.820         0     no  southeast  11090.71780
# 14   27    male  42.130         0    yes  southeast  39611.75770
# 15   19    male  24.600         1     no  southwest   1837.23700
# 16   52  female  30.780         1     no  northeast  10797.33620
# 17   23    male  23.845         0     no  northeast   2395.17155
# 18   56    male  40.300         0     no  southwest  10602.38500
# 19   30    male  35.300         0    yes  southwest  36837.46700
# 20   60  female  36.005         0     no  northeast  13228.84695

# %%
#Uso de loc para indexar al tiempo filas y columnas
patients_df.loc[10:20][['age','sex']]
# Out:
#     age     sex
# 10   25    male
# 11   62  female
# 12   23    male
# 13   56  female
# 14   27    male
# 15   19    male
# 16   52  female
# 17   23    male
# 18   56    male
# 19   30    male
# 20   60  female

# %%
# Indexación basado en condiciones, creación de un nuevo dataframe
older_patients_df=patients_df[patients_df['age']>62]
older_patients_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 26     63  female  23.085         0     no  northeast  14451.83515
# 33     63    male  28.310         0     no  northwest  13770.09790
# 62     64    male  24.700         1     no  northwest  30166.61817
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 109    63    male  35.090         0    yes  southeast  47055.53210
# 170    63    male  41.470         0     no  southeast  13405.39030
# 175    63  female  37.700         0    yes  southwest  48824.45000
# 199    64  female  39.330         0     no  northeast  14901.51670
# 208    63  female  31.800         0     no  southwest  13880.94900
# 244    63  female  27.740         0    yes  northeast  29523.16560
# 251    63  female  32.200         2    yes  southwest  47305.30500
# 287    63  female  26.220         0     no  northwest  14256.19280
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 335    64    male  34.500         0     no  southwest  13822.80300
# 343    63    male  36.765         0     no  northeast  13981.85035
# 378    64  female  30.115         3     no  northwest  16455.70785
# 398    64    male  25.600         2     no  southwest  14988.43200
# 402    64  female  32.965         0     no  northwest  14692.66935
# 418    64    male  39.160         1     no  southeast  14418.28040
# 419    63  female  26.980         0    yes  northwest  28950.46920
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 480    63    male  41.325         3     no  northwest  15555.18875
# 534    64    male  40.480         0     no  southeast  13831.11520
# 542    63  female  36.300         0     no  southeast  13887.20400
# 550    63    male  30.800         0     no  southwest  13390.55900
# 603    64  female  39.050         3     no  southeast  16085.12750
# 635    64    male  38.190         0     no  northeast  14410.93210
# 664    64  female  22.990         0    yes  southeast  27037.91410
# 752    64    male  37.905         0     no  northwest  14210.53595
# 768    64  female  39.700         0     no  southwest  14319.03100
# 801    64  female  35.970         0     no  southeast  14313.84630
# 825    64  female  31.825         2     no  northeast  16069.08475
# 830    63    male  33.100         0     no  southwest  13393.75600
# 890    64  female  26.885         0    yes  northwest  29330.98315
# 908    63    male  39.800         3     no  southwest  15170.06900
# 962    63  female  35.200         1     no  southeast  14474.67500
# 997    63  female  36.850         0     no  southeast  13887.96850
# 1051   64    male  26.410         0     no  northeast  14394.55790
# 1068   63    male  21.660         1     no  northwest  14349.85440
# 1071   63    male  31.445         0     no  northeast  13974.45555
# 1079   63    male  33.660         3     no  southeast  15161.53440
# 1125   63  female  25.080         0     no  northwest  14254.60820
# 1236   63  female  21.660         0     no  northeast  14449.85440
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1265   64    male  23.760         0    yes  southeast  26926.51440

# %%
# Indexación basado en condiciones
patients_df[ (patients_df['age']>62) | (patients_df['smoker']=='yes')]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 11     62  female  26.290         0    yes  southeast  27808.72510
# 14     27    male  42.130         0    yes  southeast  39611.75770
# 19     30    male  35.300         0    yes  southwest  36837.46700
# 23     34  female  31.920         1    yes  northeast  37701.87680
# ...   ...     ...     ...       ...    ...        ...          ...
# 1313   19  female  34.700         2    yes  southwest  36397.57600
# 1314   30  female  23.655         3    yes  northwest  18765.87545
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [307 rows x 7 columns]

# %%
# Ordenar
older_patients_df.sort_values(by=['age','bmi'])
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1068   63    male  21.660         1     no  northwest  14349.85440
# 1236   63  female  21.660         0     no  northeast  14449.85440
# 26     63  female  23.085         0     no  northeast  14451.83515
# 1125   63  female  25.080         0     no  northwest  14254.60820
# 287    63  female  26.220         0     no  northwest  14256.19280
# 419    63  female  26.980         0    yes  northwest  28950.46920
# 244    63  female  27.740         0    yes  northeast  29523.16560
# 33     63    male  28.310         0     no  northwest  13770.09790
# 550    63    male  30.800         0     no  southwest  13390.55900
# 1071   63    male  31.445         0     no  northeast  13974.45555
# 208    63  female  31.800         0     no  southwest  13880.94900
# 251    63  female  32.200         2    yes  southwest  47305.30500
# 830    63    male  33.100         0     no  southwest  13393.75600
# 1079   63    male  33.660         3     no  southeast  15161.53440
# 109    63    male  35.090         0    yes  southeast  47055.53210
# 962    63  female  35.200         1     no  southeast  14474.67500
# 542    63  female  36.300         0     no  southeast  13887.20400
# 343    63    male  36.765         0     no  northeast  13981.85035
# 997    63  female  36.850         0     no  southeast  13887.96850
# 175    63  female  37.700         0    yes  southwest  48824.45000
# 908    63    male  39.800         3     no  southwest  15170.06900
# 480    63    male  41.325         3     no  northwest  15555.18875
# 170    63    male  41.470         0     no  southeast  13405.39030
# 664    64  female  22.990         0    yes  southeast  27037.91410
# 1265   64    male  23.760         0    yes  southeast  26926.51440
# 62     64    male  24.700         1     no  northwest  30166.61817
# 398    64    male  25.600         2     no  southwest  14988.43200
# 1051   64    male  26.410         0     no  northeast  14394.55790
# 890    64  female  26.885         0    yes  northwest  29330.98315
# 378    64  female  30.115         3     no  northwest  16455.70785
# 94     64  female  31.300         2    yes  southwest  47291.05500
# 825    64  female  31.825         2     no  northeast  16069.08475
# 402    64  female  32.965         0     no  northwest  14692.66935
# 328    64  female  33.800         1    yes  southwest  47928.03000
# 420    64    male  33.880         0    yes  southeast  46889.26120
# 335    64    male  34.500         0     no  southwest  13822.80300
# 801    64  female  35.970         0     no  southeast  14313.84630
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 752    64    male  37.905         0     no  northwest  14210.53595
# 635    64    male  38.190         0     no  northeast  14410.93210
# 603    64  female  39.050         3     no  southeast  16085.12750
# 418    64    male  39.160         1     no  southeast  14418.28040
# 199    64  female  39.330         0     no  northeast  14901.51670
# 768    64  female  39.700         0     no  southwest  14319.03100
# 534    64    male  40.480         0     no  southeast  13831.11520

# %%
# tipos de datos de las columnas
older_patients_df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %% [markdown]
# ### Estadísticas descriptivas del conjunto de datos
#
# Pandas puede ser usado para dar estadisticas descriptivas de los datos

# %%
patients_df[['age','bmi','children','charges']].describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
patients_df[['sex','region','smoker']].describe()
# Out:
#          sex     region smoker
# count   1338       1338   1338
# unique     2          4      2
# top     male  southeast     no
# freq     676        364   1064

# %%
patients_df[['sex','region','smoker']].value_counts()
# Out:
# sex     region     smoker
# female  southwest  no        141
#         southeast  no        139
#         northwest  no        135
# male    southeast  no        134
# female  northeast  no        132
# male    northwest  no        132
#         southwest  no        126
#         northeast  no        125
#         southeast  yes        55
#         northeast  yes        38
#         southwest  yes        37
# female  southeast  yes        36
#         northeast  yes        29
#         northwest  yes        29
# male    northwest  yes        29
# female  southwest  yes        21
# Name: count, dtype: int64

# %% [markdown]
# ### Creación de variables dummy para variables categóricas
#
# Como la regresión linear solo funciona con variables númericas, debemos crear variables dummy para las variables categóricas. Como  smoker y sex son variables binarias, podemos sustituir los valores por 1 o 0. Para la variable region debemos crear una variable por cada categoría.

# %%
# Creación variables binarias
patients_df.replace({'sex':{'male':0,'female':1}}, inplace=True)
patients_df.replace({'smoker':{'yes':1,'no':0}}, inplace=True)
# Out:
# <ipython-input-24-ef7179c2254e>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   patients_df.replace({'sex':{'male':0,'female':1}}, inplace=True)
# <ipython-input-24-ef7179c2254e>:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   patients_df.replace({'smoker':{'yes':1,'no':0}}, inplace=True)

# %%
patients_df
# Out:
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# La función get dummies convierte un DataFrame de columnas categóricas a uno con variables dummy variables
region_dummies_df=pd.get_dummies(patients_df[['region']])
region_dummies_df
# Out:
#       region_northeast  region_northwest  region_southeast  region_southwest
# 0                False             False             False              True
# 1                False             False              True             False
# 2                False             False              True             False
# 3                False              True             False             False
# 4                False              True             False             False
# ...                ...               ...               ...               ...
# 1333             False              True             False             False
# 1334              True             False             False             False
# 1335             False             False              True             False
# 1336             False             False             False              True
# 1337             False              True             False             False
#
# [1338 rows x 4 columns]

# %%
# Hacemos join entre los 2 dataframes para reconstruir el dataset
patients_df = patients_df.join(region_dummies_df)

# %%
patients_df
# Out:
#       age  sex     bmi  children  smoker     region      charges  \
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# 1334   18    1  31.920         0       0  northeast   2205.98080
# 1335   18    1  36.850         0       0  southeast   1629.83350
# 1336   21    1  25.800         0       0  southwest   2007.94500
# 1337   61    1  29.070         0       1  northwest  29141.36030
#
#       region_northeast  region_northwest  region_southeast  region_southwest
# 0                False             False             False              True
# 1                False             False              True             False
# 2                False             False              True             False
# 3                False              True             False             False
# 4                False              True             False             False
# ...                ...               ...               ...               ...
# 1333             False              True             False             False
# 1334              True             False             False             False
# 1335             False             False              True             False
# 1336             False             False             False              True
# 1337             False              True             False             False
#
# [1338 rows x 11 columns]

# %% [markdown]
# ### Partición de datos
#
# Siempre que queramos construir un modelo de aprendizaje de máquina supervisado, debemos contar con un dataset de test que nos permita estimar el error sobre datos nuevos independientes del proceso de entrenamiento. Vamos a particionar el dataset anterior en 3:
#
# *   Training dataset: Instancias que se van a usar para minimizar la función de pérdida
# *   Validation dataset: Instancias que se van a usar para seleccionar el modelo
# *   Test dataset: Instancias que se van a usar para estimar el error sobre datos no vistos anteriormente.

# %%
# Uso 70% para entrenamiento (random split)
train_df= patients_df.sample(frac=0.7,random_state=200)
rest_df = patients_df.drop(train_df.index)
# Uso 15% para validacion y 15% para test
val_df=rest_df.sample(frac=0.5,random_state=200)
test_df=rest_df.drop(val_df.index)

# %%
train_df.shape
# Out:
# (937, 11)

# %%
val_df.shape
# Out:
# (200, 11)

# %%
test_df.shape
# Out:
# (201, 11)

# %% [markdown]
# # Exploración
#
# Inicialmente nos preocuparemos solamente por las variables `age` y `charges`, visualizemos la relación entre estas:

# %%
train_df[['age','charges']].sample(50)
# Out:
#       age      charges
# 1022   47  42211.13820
# 830    63  13393.75600
# 118    49   8601.32930
# 671    29   3943.59540
# 47     28   3556.92230
# 862    55  12269.68865
# 698    56  10976.24575
# 896    43  19798.05455
# 9      60  28923.13692
# 766    47   8062.76400
# 991    38   7144.86265
# 878    41   6282.23500
# 1037   45  39725.51805
# 402    64  14692.66935
# 306    28  20177.67113
# 1130   39   8582.30230
# 1201   46   8733.22925
# 260    58  11837.16000
# 8      37   6406.41070
# 213    34   5002.78270
# 101    30   3645.08940
# 391    19   2138.07070
# 471    18   2203.47185
# 863    36   5458.04645
# 79     41   6571.02435
# 779    53   9869.81020
# 356    46   8944.11510
# 1221   40   6593.50830
# 973    19   1759.33800
# 1099   25   3227.12110
# 1016   19   2709.24395
# 436    22   2254.79670
# 1177   40   6496.88600
# 62     64  30166.61817
# 1288   20  38344.56600
# 955    31   3875.73410
# 311    19   1737.37600
# 972    22   2527.81865
# 1029   37   6877.98010
# 114    52  11488.31695
# 54     40   8059.67910
# 430    19  23082.95533
# 537    46   8825.08600
# 568    49  11552.90400
# 1283   18   1720.35370
# 323    57  11566.30055
# 553    52  11187.65670
# 898    18   1634.57340
# 910    22   2639.04290
# 451    30   4032.24070

# %%
# Lleva Series a vector numpy
X= train_df[['age']].values

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X.shape
# Out:
# (937, 1)

# %%
# Lleva Series a vector numpy
Y= train_df[['charges']].values

# %%
Y.shape
# Out:
# (937, 1)

# %%
# Dibujamos diagrama de dispersión entre variables.
plt.scatter(X, Y, alpha=.3)
plt.show()

# %% [markdown]
# Inflamos X para añadir la columna constante de unos.

# %%
X_c=np.hstack((np.ones((X.shape[0],1)),X))

# %%
X_c.shape
# Out:
# (937, 2)

# %%
n = X_c.shape[0] # numero de filas
m = X_c.shape[1] # numero de columnas

# %% [markdown]
# ## Decenso de gradiente
#
# La tarea de su grupo es implementar el algoritmo de decenso de gradiente sobre este dataset. Comenzaremos por algunos pasos:
#
# ## Inicialización de $\theta$ aleatorio

# %%
theta = np.random.rand(m,1)

# %%
theta
# Out:
# array([[0.06080067],
#        [0.27781324]])

# %%
theta.shape
# Out:
# (2, 1)

# %% [markdown]
# Midamos qué tan bueno es este theta aleatorio
#
# $\hat{Y}= X  \theta$

# %%
Y_est=X_c.dot(theta) #producto punto?

# %% [markdown]
# $\hat{Y}-Y$

# %%
Y_est - Y
# Out:
# array([[-10104.47253753],
#        [ -8954.90023312],
#        [-26223.46194724],
#        [ -8591.26100371],
#        [ -3169.00375519],
#        [ -2398.83892137],
#        [-48659.62154487],
#        [ -1641.09044785],
#        [-39973.64168607],
#        [ -7717.91679342],
#        [-41648.76179047],
#        [-11057.55765811],
#        [-28327.62645371],
#        [-13714.02069665],
#        [-11929.23654487],
#        [ -4348.09282578],
#        [-13903.09330517],
#        [-36144.42206108],
#        [ -7728.05241694],
#        [ -7737.70525665],
#        [ -7715.24643018],
#        [-23077.61607785],
#        [ -9398.16479047],
#        [-41022.21463018],
#        [ -4445.45182578],
#        [ -1621.94319785],
#        [-15353.20962137],
#        [-12079.41528458],
#        [ -9553.31725076],
#        [-48500.55574193],
#        [-12578.02741105],
#        [ -8112.11085076],
#        [ -4873.80392283],
#        [ -4898.29226548],
#        [-14127.97631108],
#        [ -7501.37148312],
#        [-12090.25728458],
#        [ -1620.09449785],
#        [-13440.67557869],
#        [ -2096.36982137],
#        [-37459.72668461],
#        [-46138.28429047],
#        [-36302.73686108],
#        [ -9570.21965076],
#        [-11826.26803164],
#        [-12206.72433164],
#        [-12933.06379193],
#        [-25319.38137753],
#        [ -1697.39386108],
#        [-12228.0792184 ],
#        [-23230.00529782],
#        [-10546.26242429],
#        [-31602.71583869],
#        [-39992.15891989],
#        [-12714.27000517],
#        [-46582.10099193],
#        [ -9126.44391105],
#        [ -2527.38761843],
#        [-38699.11392283],
#        [ -2191.41176108],
#        [-19434.23611548],
#        [ -5980.0171993 ],
#        [-14238.62976546],
#        [-33470.20008461],
#        [-13990.7702184 ],
#        [ -5404.48786989],
#        [ -1628.90036108],
#        [-43905.56535811],
#        [-20269.69012548],
#        [-11863.76352135],
#        [ -7332.52160371],
#        [-44245.68718458],
#        [ -4878.97472283],
#        [-18794.13870018],
#        [ -3476.80656108],
#        [-34823.31474785],
#        [-38233.86431342],
#        [ -2097.18512137],
#        [ -3273.97367137],
#        [ -3161.56097137],
#        [-10913.78628458],
#        [ -1978.83623461],
#        [-17655.30462872],
#        [-12254.34812135],
#        [ -2214.38366108],
#        [-21071.26448312],
#        [-13453.57477869],
#        [-12627.85940517],
#        [-10029.853164  ],
#        [ -8255.648164  ],
#        [ -8504.26660371],
#        [-11149.79930811],
#        [-36563.27475193],
#        [ -4065.50287578],
#        [-23281.08882872],
#        [-12605.7277184 ],
#        [ -8103.98426694],
#        [ -2919.78075519],
#        [-12912.3393184 ],
#        [ -2637.09580814],
#        [ -7628.58024342],
#        [-12016.42984487],
#        [-13212.11735517],
#        [-13813.27435222],
#        [ -4389.66892283],
#        [ -1131.33796108],
#        [ -8414.95127724],
#        [-12215.43963164],
#        [ -4993.2762493 ],
#        [-25367.23428458],
#        [ -6699.29638312],
#        [ -9616.44553753],
#        [ -3071.20062137],
#        [-36392.23674785],
#        [-18948.49185167],
#        [-12317.3762184 ],
#        [ -1817.8348949 ],
#        [-39712.95565371],
#        [ -3403.04005519],
#        [-11378.72502135],
#        [ -1158.40126108],
#        [ -6071.78729636],
#        [-11658.51165811],
#        [-10949.54984487],
#        [ -4175.86926254],
#        [-19031.64736254],
#        [-48953.7958184 ],
#        [ -9630.02322429],
#        [ -3169.53195519],
#        [-44495.22550814],
#        [ -5106.71613607],
#        [ -9549.633164  ],
#        [-44189.53557724],
#        [ -7233.75152283],
#        [ -1959.16293461],
#        [ -1256.10274785],
#        [ -7190.80533312],
#        [-10421.03328458],
#        [ -3014.80301843],
#        [ -4880.77086254],
#        [-20974.30933607],
#        [ -8591.92125371],
#        [-18250.82080225],
#        [ -1250.95974785],
#        [-27202.54109487],
#        [ -9289.05334047],
#        [-38405.41192283],
#        [ -6975.1670596 ],
#        [ -2251.85818461],
#        [ -4231.21963901],
#        [-46646.65749782],
#        [-33744.95254785],
#        [-26093.71070811],
#        [ -4709.80835225],
#        [ -2632.87020814],
#        [ -7614.70841694],
#        [-22466.59323018],
#        [ -9852.07557429],
#        [-26983.69950869],
#        [-11473.80986105],
#        [-43884.64734342],
#        [-36189.58161548],
#        [ -4454.53208901],
#        [-14278.39796108],
#        [ -8974.48510076],
#        [-48156.63140517],
#        [ -9433.854514  ],
#        [ -3201.78086843],
#        [-14301.19015222],
#        [-11340.76474487],
#        [-21218.786424  ],
#        [ -2202.63601108],
#        [ -3870.02030519],
#        [-21247.64899342],
#        [-24902.10282724],
#        [ -1980.20508167],
#        [ -1509.45002137],
#        [ -8526.55297724],
#        [-10323.86888458],
#        [ -5651.32948312],
#        [ -7526.54619636],
#        [-14400.43955222],
#        [ -1236.92074785],
#        [ -2123.09179785],
#        [-12113.1623684 ],
#        [-12933.53705811],
#        [-36014.5606949 ],
#        [ -1974.45293461],
#        [ -6392.50708607],
#        [-20410.2647596 ],
#        [-13334.81457869],
#        [ -7333.71983018],
#        [-14376.71705222],
#        [-16570.21774196],
#        [-10776.61947135],
#        [ -3551.05849196],
#        [-14102.61259193],
#        [-29313.14230222],
#        [-28932.90616546],
#        [-38119.51818167],
#        [-14434.27211546],
#        [-36077.93505519],
#        [-30925.18439193],
#        [ -2212.40771108],
#        [ -8931.27489047],
#        [ -6301.6121096 ],
#        [ -1763.91458461],
#        [-24379.11531105],
#        [-10698.30347135],
#        [ -3199.48521843],
#        [-12995.47905517],
#        [ -1703.86431108],
#        [ -3494.1617949 ],
#        [ -3974.69285519],
#        [ -6867.6402096 ],
#        [ -2890.03955519],
#        [ -8443.86653753],
#        [ -6069.05379636],
#        [-11135.99509782],
#        [-16649.60006548],
#        [-11866.62907135],
#        [ -9865.83872429],
#        [ -7335.57960371],
#        [-10550.09959782],
#        [ -6193.5618596 ],
#        [-58562.40146901],
#        [-18755.73093018],
#        [-14565.16248167],
#        [ -5700.74961548],
#        [-18218.38976108],
#        [ -2703.90469785],
#        [-11538.32744487],
#        [-23793.56695076],
#        [-12125.84900517],
#        [-11719.70508164],
#        [-13031.99182135],
#        [ -1610.70526108],
#        [ -1961.40563461],
#        [ -8070.80177724],
#        [ -7134.26479047],
#        [ -6425.2838096 ],
#        [-20693.12418487],
#        [-10966.60514487],
#        [ -5574.24362283],
#        [ -4941.08568901],
#        [-39585.95605665],
#        [ -4421.04827872],
#        [-32543.00124785],
#        [-12330.7202184 ],
#        [ -7150.28324342],
#        [-11539.23035076],
#        [ -1722.44574785],
#        [ -8503.19630371],
#        [-19191.27098901],
#        [-14218.06459193],
#        [ -8015.40560371],
#        [ -1726.33774785],
#        [-12557.04159193],
#        [ -9274.35305076],
#        [ -2206.06931108],
#        [-12631.97380517],
#        [-39713.94035076],
#        [ -7435.84155371],
#        [-20865.66640724],
#        [ -1247.06774785],
#        [-24167.537664  ],
#        [ -8812.24579047],
#        [-14706.12673461],
#        [-11971.82767135],
#        [-46871.42035222],
#        [-11714.89459782],
#        [-25978.31395105],
#        [ -9863.37842429],
#        [ -8264.127164  ],
#        [-37732.51362283],
#        [ -5139.60177578],
#        [ -5367.39572283],
#        [-19710.74387578],
#        [ -2195.76941108],
#        [ -6447.22569636],
#        [-23052.30267724],
#        [ -2768.7416449 ],
#        [-10782.82911105],
#        [-13445.23477869],
#        [ -9159.90637429],
#        [ -7185.69366989],
#        [-11477.57341108],
#        [ -1743.43474785],
#        [ -5845.28479636],
#        [-13095.87520517],
#        [ -9858.47172429],
#        [ -9168.49635076],
#        [-11726.8472184 ],
#        [ -7346.72450665],
#        [-35482.1335493 ],
#        [ -8602.73760371],
#        [-26452.59028105],
#        [ -4682.45774785],
#        [-15152.50596546],
#        [-47910.18915222],
#        [-20161.71896461],
#        [ -7714.56941694],
#        [ -3285.24590519],
#        [ -1624.77206108],
#        [ -2389.6453949 ],
#        [ -8751.853164  ],
#        [-12909.4342184 ],
#        [ -6396.0708096 ],
#        [-37158.99110814],
#        [ -8151.54291989],
#        [-11337.33144487],
#        [ -5317.25580225],
#        [-11274.60216105],
#        [-12627.75945811],
#        [-11878.98714108],
#        [ -5447.98437283],
#        [-11560.23384487],
#        [-12480.22813458],
#        [-26126.68665076],
#        [-15810.97956843],
#        [-11054.91665811],
#        [-12217.3762184 ],
#        [-13870.40546546],
#        [ -8290.25106694],
#        [ -2966.56424196],
#        [-19528.9031096 ],
#        [ -3685.86624196],
#        [ -5924.59553607],
#        [-41905.14553753],
#        [-12464.64623458],
#        [ -4425.27031548],
#        [-14237.04516546],
#        [-21463.52797578],
#        [ -2132.73144785],
#        [-16130.64466548],
#        [-11329.34503164],
#        [ -7210.22385371],
#        [ -9527.74408753],
#        [-20000.1271993 ],
#        [-46113.79690517],
#        [ -3345.90854196],
#        [-10963.53265076],
#        [ -6837.01923018],
#        [ -1699.50666108],
#        [-13742.81091108],
#        [-13126.32924193],
#        [ -4556.12706108],
#        [ -8048.50576989],
#        [ -1627.98296108],
#        [ -1668.45960814],
#        [-18833.36440785],
#        [-11820.98603164],
#        [ -7429.49423018],
#        [ -2486.46024196],
#        [ -2748.84825814],
#        [ -1131.94956108],
#        [-11928.42038164],
#        [ -6738.52912283],
#        [-13414.64665811],
#        [-14366.2572684 ],
#        [ -8220.25729047],
#        [ -5826.73613607],
#        [-17936.21112137],
#        [-24905.26199607],
#        [-24590.20816047],
#        [-12108.5406184 ],
#        [ -9371.93202429],
#        [ -6404.39373607],
#        [-14448.36010519],
#        [ -8821.31348753],
#        [ -1837.17974785],
#        [ -7313.04143018],
#        [-28851.65649193],
#        [-16580.60283137],
#        [-15513.11881108],
#        [-20766.14839135],
#        [ -2895.62255519],
#        [ -6345.37518312],
#        [-63755.36529458],
#        [-14457.11196546],
#        [-46188.70051694],
#        [ -2193.12841108],
#        [ -8784.36372429],
#        [-11831.96703164],
#        [ -2248.62400814],
#        [-10833.90502429],
#        [ -1971.08668167],
#        [ -3650.95080225],
#        [ -2200.91936108],
#        [-37692.3703493 ],
#        [-13453.51917869],
#        [ -6769.90305665],
#        [ -3963.97387578],
#        [ -6589.18766989],
#        [ -6102.0130596 ],
#        [-14970.59115222],
#        [-16412.93279196],
#        [-44992.22590517],
#        [-10781.00972135],
#        [ -5386.99899636],
#        [ -6644.55996254],
#        [ -1903.63257137],
#        [-30168.4849184 ],
#        [ -4049.99871548],
#        [-11826.72759487],
#        [ -5218.20448607],
#        [ -8227.74939047],
#        [ -8526.83730665],
#        [ -7407.62648312],
#        [ -3385.08125519],
#        [ -6119.84662578],
#        [ -2476.17424196],
#        [-14674.82850222],
#        [ -6790.78498901],
#        [-12613.26944487],
#        [ -3378.11520519],
#        [ -9130.05791105],
#        [-10340.85609782],
#        [-27020.07325222],
#        [-29171.69745782],
#        [-36894.1562484 ],
#        [ -4253.18224196],
#        [ -2681.65582872],
#        [-17487.35517578],
#        [-41984.45728458],
#        [-21649.03458312],
#        [-36941.86150225],
#        [-24522.58052724],
#        [-13002.98708164],
#        [ -9250.56772429],
#        [ -8013.82639047],
#        [-35144.79404135],
#        [ -5262.11372283],
#        [-13120.2269449 ],
#        [ -2131.54299785],
#        [-11020.265864  ],
#        [ -9976.53056105],
#        [ -3251.52598901],
#        [ -1720.49086108],
#        [-20614.94298135],
#        [ -1702.93996108],
#        [ -3899.12086843],
#        [ -1617.12706108],
#        [-14026.19147869],
#        [-39233.04680225],
#        [ -4067.54617578],
#        [ -5372.91829636],
#        [ -2150.57910814],
#        [ -1626.75976108],
#        [ -1974.85358167],
#        [ -4752.54473607],
#        [ -5837.13333607],
#        [ -5477.64429636],
#        [-11747.38255811],
#        [-15810.08129636],
#        [-18211.15525843],
#        [-35579.40330814],
#        [ -7140.38681694],
#        [-37070.14336254],
#        [ -9268.80695076],
#        [-38737.68208901],
#        [ -2148.18830814],
#        [ -8813.25843753],
#        [ -5256.30352283],
#        [-13599.35119193],
#        [ -3839.83442872],
#        [ -4509.3197993 ],
#        [-41083.21028753],
#        [ -7505.74076694],
#        [-10357.23890076],
#        [ -4384.64586843],
#        [ -2579.37412137],
#        [ -3054.66867872],
#        [ -4664.44137578],
#        [-17463.64464785],
#        [ -1732.03674785],
#        [-11726.94109782],
#        [-36182.6511949 ],
#        [ -4518.78775225],
#        [ -7134.24494636],
#        [-11267.26995108],
#        [ -2692.28440519],
#        [ -1602.44866108],
#        [-20763.56567283],
#        [ -5963.14936254],
#        [-35589.41710814],
#        [ -6327.18008312],
#        [-42971.17391694],
#        [ -8918.13253753],
#        [ -1809.4253949 ],
#        [ -2346.24013167],
#        [-12130.24140517],
#        [ -3867.06108901],
#        [-11727.76013164],
#        [ -4829.18710225],
#        [-11173.14961105],
#        [-19433.09246989],
#        [ -3857.90437578],
#        [-18797.19064196],
#        [-11071.63533753],
#        [ -4825.01293461],
#        [-33901.37530814],
#        [-22389.2937349 ],
#        [ -3747.94858901],
#        [ -9861.45112429],
#        [ -1385.91163461],
#        [-11922.08198164],
#        [ -4341.62242872],
#        [ -4453.77097578],
#        [ -6975.52366989],
#        [ -9603.71098753],
#        [-12897.5406184 ],
#        [ -5420.33250225],
#        [-16107.18711548],
#        [ -4885.2468493 ],
#        [ -1616.82126108],
#        [-10050.62809782],
#        [ -8206.91931694],
#        [-47287.74196546],
#        [-13984.6820184 ],
#        [ -2857.97361548],
#        [ -1911.42352137],
#        [ -2859.00221548],
#        [ -6485.71266989],
#        [-13752.53486546],
#        [-11817.60833164],
#        [ -8614.42307724],
#        [-39604.19594196],
#        [-44577.33848548],
#        [-35140.80016167],
#        [ -3483.26515519],
#        [-39544.20991694],
#        [-19786.04778018],
#        [-42548.42363018],
#        [ -1830.8313949 ],
#        [ -6864.50985665],
#        [ -4636.4191096 ],
#        [-36829.07180225],
#        [-42842.88653753],
#        [ -6049.94436254],
#        [-20286.5235596 ],
#        [-23873.15561105],
#        [-23388.18772724],
#        [-19099.66221548],
#        [ -7513.86624047],
#        [ -6589.03261989],
#        [-10071.06109782],
#        [-29124.35289193],
#        [-45692.92262869],
#        [ -9180.99829047],
#        [-18641.69338167],
#        [ -2782.6068949 ],
#        [-24652.91191105],
#        [-21975.24197254],
#        [ -2450.77368167],
#        [ -1699.63871108],
#        [-37259.8113096 ],
#        [-38338.94893461],
#        [ -6303.4191096 ],
#        [ -8534.57327724],
#        [ -8430.52253753],
#        [ -8571.40678312],
#        [-40897.7489949 ],
#        [ -1900.46337137],
#        [-12395.65046254],
#        [ -8055.06697724],
#        [-12724.43785517],
#        [-11642.49670811],
#        [-30148.77732222],
#        [ -8594.21063018],
#        [ -8585.93228312],
#        [ -9835.36928458],
#        [-28906.40732517],
#        [-34466.11268167],
#        [-14466.32338018],
#        [ -6382.43011989],
#        [-34298.10576108],
#        [ -3999.24980814],
#        [-19582.52506694],
#        [ -8428.71553753],
#        [ -2216.22519785],
#        [-44626.96812429],
#        [-16437.86700222],
#        [ -4257.77060225],
#        [-47880.3395684 ],
#        [ -1874.45293461],
#        [ -3759.04422872],
#        [ -8198.81561694],
#        [-12470.46037135],
#        [-17916.74097371],
#        [-12630.31084487],
#        [ -4142.63350225],
#        [-17353.37090225],
#        [-11290.87183458],
#        [ -3261.00707872],
#        [ -3037.48498167],
#        [-46700.87802869],
#        [ -8720.38904047],
#        [ -1526.57482137],
#        [ -3050.77103461],
#        [-27307.67114458],
#        [-33457.46480105],
#        [ -5252.24081254],
#        [ -5473.84959636],
#        [ -1528.40962137],
#        [ -2798.35859785],
#        [-10255.78635076],
#        [ -8398.04008018],
#        [-25642.62379753],
#        [-11814.71104487],
#        [ -4497.65626843],
#        [ -7790.764664  ],
#        [-12347.92865811],
#        [-22451.14823312],
#        [ -5390.36279636],
#        [-40960.769064  ],
#        [ -9776.30350371],
#        [-18962.9885493 ],
#        [ -5304.33027872],
#        [ -2014.28212137],
#        [-10579.16102135],
#        [-14432.29136546],
#        [ -4677.43787578],
#        [ -1136.38366108],
#        [-10585.79365811],
#        [ -4661.68917578],
#        [-46240.88322429],
#        [ -1616.00094785],
#        [ -2315.33785519],
#        [ -5620.67358607],
#        [ -8538.22897724],
#        [ -3345.16661548],
#        [-23031.05907105],
#        [-17173.62096108],
#        [ -7318.67338008],
#        [ -3935.47801548],
#        [-10393.96782724],
#        [ -8514.96960371],
#        [ -8110.73475076],
#        [ -1737.87474785],
#        [-37598.57687578],
#        [-27924.28017193],
#        [-12460.28858458],
#        [ -4711.12885225],
#        [ -6922.62454636],
#        [ -1872.31233461],
#        [-11271.19817135],
#        [ -8321.61734047],
#        [-38505.1777949 ],
#        [ -3530.97468167],
#        [ -4125.80207872],
#        [ -8543.78897724],
#        [-12506.87520517],
#        [-13920.38127869],
#        [-51186.71956872],
#        [-24664.37939519],
#        [-10586.59683753],
#        [-19486.93490607],
#        [ -9943.49232429],
#        [-20225.07048607],
#        [ -1739.12574785],
#        [-24461.41579458],
#        [ -1874.86993461],
#        [-27518.01674487],
#        [-37126.33644196],
#        [-11365.15143164],
#        [ -3220.11496843],
#        [-52574.09979517],
#        [-38787.62416108],
#        [-10792.33191105],
#        [-17554.76268461],
#        [ -2724.76859785],
#        [ -6657.01436254],
#        [ -8321.74939047],
#        [ -5638.81948312],
#        [-26013.05564137],
#        [-13200.36490517],
#        [ -3549.08272872],
#        [ -5244.57317578],
#        [-10407.85393458],
#        [-16788.85018196],
#        [-17121.69776167],
#        [ -2111.99959785],
#        [ -5607.52942872],
#        [ -4658.65682578],
#        [-19926.45186843],
#        [-47386.87259193],
#        [ -1132.40826108],
#        [ -6261.02605665],
#        [-21780.5486184 ],
#        [ -2198.41041108],
#        [ -4982.8699493 ],
#        [ -7271.1657096 ],
#        [ -8587.65565076],
#        [ -9949.83072429],
#        [ -2466.60578167],
#        [ -8592.79910371],
#        [-17079.65053461],
#        [-17743.16694785],
#        [ -1700.56306108],
#        [-10944.90979782],
#        [ -7621.43601694],
#        [-34159.8224949 ],
#        [-20737.59390225],
#        [ -5968.00204342],
#        [ -7142.10275665],
#        [ -2474.25078167],
#        [ -4234.91703901],
#        [ -7407.19331694],
#        [ -4432.54013901],
#        [ -6538.13297283],
#        [ -6825.36193018],
#        [-10143.10955076],
#        [-19132.56975018],
#        [-17347.34104785],
#        [ -3585.0294949 ],
#        [-11914.95128164],
#        [ -3388.29491108],
#        [ -8950.664714  ],
#        [-43563.04324487],
#        [ -7729.26959047],
#        [ -6445.24494636],
#        [-21965.55887724],
#        [-39114.15891989],
#        [ -1248.59674785],
#        [ -6544.45264636],
#        [-12208.17688164],
#        [ -6270.78385665],
#        [ -4392.17092283],
#        [-10578.60735811],
#        [-36893.39382785],
#        [ -1630.39439785],
#        [ -1715.29226108],
#        [ -4129.12750225],
#        [ -4922.97398901],
#        [-12603.15870167],
#        [ -2149.50880814],
#        [-13433.83677869],
#        [-13537.71967869],
#        [-33727.62526108],
#        [-42198.02017724],
#        [ -9855.02529782],
#        [-42098.82449047],
#        [ -9620.03091105],
#        [ -8857.755864  ],
#        [ -1626.69699785],
#        [ -8689.78235076],
#        [ -3636.69420225],
#        [ -3695.12586254],
#        [-43798.24775811],
#        [-24858.59999782],
#        [ -7612.34541694],
#        [ -8768.23972429],
#        [-24506.31253753],
#        [-12824.39366108],
#        [-11001.778864  ],
#        [ -1869.72693461],
#        [ -4141.34080225],
#        [ -4290.09850814],
#        [-19341.69588901],
#        [-19352.21453607],
#        [ -1753.99874785],
#        [ -9291.02825076],
#        [ -2703.77264785],
#        [ -2489.47654196],
#        [-10084.12979047],
#        [-18954.77672225],
#        [ -7360.32085665],
#        [-10561.46865811],
#        [ -5427.57576989],
#        [-18757.48025225],
#        [ -9710.02291105],
#        [-16292.50674785],
#        [ -6736.68042283],
#        [ -5230.98073607],
#        [-11550.40439487],
#        [-13187.55605517],
#        [ -6351.76496254],
#        [ -1257.90974785],
#        [-33302.21154785],
#        [ -4526.7525493 ],
#        [-20448.21275782],
#        [-40092.99448312],
#        [-34664.30762872],
#        [ -8241.11096989],
#        [-12964.06047869],
#        [-14419.6233449 ],
#        [ -5115.43143607],
#        [-10998.64918458],
#        [ -2683.6632949 ],
#        [ -9787.21455076],
#        [ -1966.22168167],
#        [-20169.83155872],
#        [-48872.85102694],
#        [-13387.82726546],
#        [ -3206.61591843],
#        [ -4490.8327993 ],
#        [-11523.35828458],
#        [ -8556.74377724],
#        [ -1256.51974785],
#        [-30048.24002135],
#        [ -5248.27931254],
#        [-45851.19823018],
#        [ -4741.28573607],
#        [ -1629.51196108],
#        [-27366.3983293 ],
#        [-42956.73467724],
#        [-43934.3696493 ],
#        [ -3545.80780225],
#        [ -5917.06173607],
#        [ -7974.91948312],
#        [ -9764.67355076],
#        [ -8521.55377724],
#        [-39861.3644096 ],
#        [-11346.58103164],
#        [ -9607.21267724],
#        [-21181.03309782],
#        [ -9489.52539782],
#        [ -3039.33368167],
#        [ -5966.21339636],
#        [ -4023.84550225],
#        [-11505.87057429],
#        [ -9420.08509047],
#        [-12798.9931684 ],
#        [ -6227.40248312],
#        [-10101.89082724],
#        [ -3231.42956843],
#        [ -8675.18520076],
#        [ -3728.34731548],
#        [-13964.28731546],
#        [ -6462.28404342],
#        [-11317.48623254],
#        [-11148.78309782],
#        [-21210.279964  ],
#        [ -7198.59628312],
#        [-17617.28868578],
#        [ -2125.33664785],
#        [-15002.47482869],
#        [-10216.43718458],
#        [ -1627.22519785],
#        [-13591.19478164],
#        [-11075.09945811],
#        [ -3358.55231548],
#        [ -7038.29234342],
#        [ -9236.099364  ],
#        [ -4032.44086548],
#        [-12414.77938164],
#        [ -2451.59408461],
#        [ -3269.32142872],
#        [ -5002.9645493 ],
#        [ -7034.99324342],
#        [ -7433.35560371],
#        [-15817.64839989],
#        [ -5257.75607283],
#        [-10943.43384487],
#        [ -9082.50585371],
#        [-11249.75609782],
#        [ -5143.18317578],
#        [-14574.1802684 ],
#        [ -7123.28479636],
#        [ -9269.33272429],
#        [-11397.17791105],
#        [-13376.19296546],
#        [-10723.474914  ],
#        [ -1236.22574785],
#        [-17075.74074785],
#        [ -5467.97472283],
#        [ -5375.8314493 ],
#        [ -4711.89697872],
#        [-11422.50887429],
#        [-36117.56756843],
#        [ -7033.77004342],
#        [ -5955.15844342],
#        [ -7066.01606989],
#        [-13984.8349184 ],
#        [ -1714.37486108],
#        [ -3163.77532872],
#        [ -3436.89130814],
#        [ -8811.14554047],
#        [-12939.83277869],
#        [-10093.26913753],
#        [ -3477.04705519],
#        [ -7148.36504342],
#        [ -5114.6822493 ],
#        [-10564.92609782],
#        [-39036.9451096 ],
#        [-10960.62740811],
#        [-12884.99621108],
#        [ -1723.55774785],
#        [-34247.32503167],
#        [ -8049.64597724],
#        [ -8954.934164  ],
#        [-13024.91359193],
#        [ -2735.77530814],
#        [-14883.67585222],
#        [ -3752.61898901],
#        [ -2014.65742137],
#        [ -2410.5044949 ],
#        [ -2848.70923167],
#        [-12784.92503694],
#        [-22320.39346989],
#        [-24855.32971105],
#        [ -6278.30375665],
#        [ -5365.80936254],
#        [-10789.4868249 ],
#        [-12613.16710517],
#        [ -1144.33446108],
#        [-10447.19449782],
#        [ -2521.64595814],
#        [-26908.67355222],
#        [-18238.93374196],
#        [-40924.03430225],
#        [ -6786.5233596 ],
#        [ -6582.33496989],
#        [-39764.49203607],
#        [ -9034.07583753],
#        [ -4460.1708949 ],
#        [ -6676.0914096 ],
#        [ -7627.68849342],
#        [ -5458.94452283],
#        [ -4441.62242872],
#        [-35056.81212371],
#        [ -8103.00635076],
#        [ -9734.40351105],
#        [-25502.05091458],
#        [ -1116.81246108],
#        [-13827.51197869],
#        [-38273.52086254],
#        [ -2098.21852137],
#        [ -2144.29630814],
#        [ -4820.34319196],
#        [ -6559.57320665],
#        [-17895.29841254],
#        [-28465.56165989],
#        [ -5344.84601254],
#        [ -6106.59898312],
#        [-28084.04782869]])

# %%
#MSE - función de costo, debería reducirse en cada iteración.
np.sum( np.power(Y_est-Y,2))
# Out:
# 300297299089.08954

# %% [markdown]
# Según lo visto en clase, cree una función que realice las iteraciones necesarias para ir actualizando $\theta$ para minimizar la función de costo.
#
# * Una vez llegue a la convergencia del algoritmo, mida el performance del modelo sobre el conjunto de validación y prueba. No olvide también "inflar" los conjuntos de datos para incluir la columna constante.
#
# * Debe implementar la función `fit_model` que reciba un conjunto de datos X y unas etiquetas Y y retorne el vector `theta` ajustado.
#
# * Su código debería funcionar con conjuntos de datos de un X de tamaño arbitrario, incluya más variables en X y mida su error.
#
# * Documente su código y realice conclusiones frente al ejercicio.

# %% [markdown]
# # Solucion

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np

def fit_model(X, Y, alpha=0.001, iterations=1000, tolerance=1e-6):

    """
    Ajusta los parámetros theta usando el descenso de gradiente.

    X: ndarray, conjunto de datos de entrada (muestras x características)
    Y: ndarray, etiquetas correspondientes a las muestras
    alpha: float, tasa de aprendizaje
    iterations: int, número de iteraciones
    tolerance: float, umbral para la convergencia

    Retorna:
    theta: ndarray, parámetros ajustados del modelo
    """

    # Paso 1, determinar el numero de muestras

    m = len(Y)

    # Paso 2, Agregar la columna constante de unos para el término de intersección (bias)

    #X = np.c_[np.ones((m, 1)), X]

    #Alternativa
    X_c=np.hstack((np.ones((X.shape[0],1)),X))

    # Paso 3, Inicializar theta con ceros | Esto puede ser con un aleatorio tambien.

    theta = np.zeros((1, X.shape[1]))  # Initialize theta as a matrix of shape (1, X.shape[1])

    # Paso 4, definir la funcion de costo.

    def compute_cost(X, Y, theta):
        """
        Esta funcion toma como parametros:
        X - Array de Atributos
        Y - Array de soluciones
        theta: Array de pesos
        """
        predictions = X.dot(theta) #Calcula las prediciones como un producto punto de la matriz de atributos con la matriz de pesos
        cost = (1 / (2 * m)) * np.sum((predictions - Y) ** 2) # Calcula el costo usando el MSE
        return cost # devuelve el costo


    # Paso 5, aplicación de Descenso de gradiente
    for iteration in range(iterations):
        # Calculamos las predicciones
        predictions = X.dot(theta)

        # Calculamos el gradiente
        gradient = (1 / m) * X.T.dot(predictions - Y) #Este es el gradiente que se obtiene a través de las derivadas parciales

        # Actualizamos los parámetros theta
        theta = theta - alpha * gradient

        # Calculamos el costo para ver si convergemos
        cost = compute_cost(X, Y, theta)

        # Verificamos si el costo ha convergido
        if iteration > 0 and abs(prev_cost - cost) < tolerance:
            print(f'Convergencia alcanzada en la iteración {iteration}')
            break

        prev_cost = cost

        # Opcional: Imprimir el costo cada 100 iteraciones
        if iteration % 100 == 0:
            print(f'Iteración {iteration}: Costo = {cost}')

    return theta

# %%
X = train_df[['age']].values

Y = train_df[['charges']].values
theta = fit_model(X, Y, alpha=0.0001, iterations=1000, tolerance=1e-6)

Y_est = X.dot(theta)

Y_dif = Y-Y_est
# Out:
# Iteración 0: Costo = 130658585.53303294
# Convergencia alcanzada en la iteración 82

# %%
plt.scatter(Y, Y_est, color='blue', label='Predicted Values (Y_est)')  # Plot Y_est in blue
plt.scatter(Y, Y, color='red', label='Actual Values (Y)')  # Plot Y in red
plt.xlabel("Actual Values (y)")
plt.ylabel("Predicted Values (y_est)")
plt.title("Actual vs. Predicted Values")
plt.legend()  # Show the legend to distinguish between the colors
plt.plot([min(Y), max(Y)], [min(Y), max(Y)], color='red', linestyle='--', label="Ideal Prediction")
plt.show()

# %%
plt.plot([min(Y), max(Y)], [min(Y), max(Y)], color='red', linestyle='--', label="Ideal Prediction")
